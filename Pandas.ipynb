# %% [markdown]
# # ------------------------------------PANDAS-------------------------------------------------------------

# %% [markdown]
# ## creating dataframes from pandas

# %%
import pandas as pd
li = [1, 2, 3, 4, 5]
d1 = pd.DataFrame(li)
d1
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
li = [[5,4,3,2,1]]
d2 = pd.DataFrame(li)
d2
# Out:
#    0  1  2  3  4
# 0  5  4  3  2  1

# %%
di = {"First Name" : ['Bhide', 'Chagan', 'Peela ', 'Bappan '],"Surname" : ['Koita', 'Chatri', 'Peter', 'Batli']}
d2 = pd.DataFrame(di)
d2
# Out:
#   First Name Surname
# 0      Bhide   Koita
# 1     Chagan  Chatri
# 2     Peela    Peter
# 3    Bappan    Batli

# %% [markdown]
# ## reading CSV files

# %%
#skiprows is for how much rows we want to skip from the top 
#header is for suppose we skip the header so the headers are initialized from 0 onwards
#names is for header names
#nrows is for num of rows to be displayed
#when our data has NAN values but those are written 'Nan' so we specify using the na_values variable that even if this values
#are there in the data replace it as Nan
#We can even specifu the na_values for each col seperately suppose if in one col we want to set a val to nan and other we dont
#if there is a date col and it is in strings we use parse_dates=['Col name']

df1 = pd.read_csv('iris.csv', skiprows=1,header=None, names=['Col1', 'Col2','Col3', 'Col4', 'Col5'], nrows=5, na_values=['NA', 'Not available'])
df1
# Out:
#    Col1  Col2  Col3  Col4    Col5
# 0   5.1   3.5   1.4   0.2  setosa
# 1   4.9   3.0   1.4   0.2  setosa
# 2   4.7   3.2   1.3   0.2  setosa
# 3   4.6   3.1   1.5   0.2  setosa
# 4   5.0   3.6   1.4   0.2  setosa

# %%
df = pd.read_csv('iris.csv', index_col=0)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df[(df['sepal_length'] > 5) & (df['sepal_width'] > 2)]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 5             5.4          3.9           1.7          0.4     setosa
# 10            5.4          3.7           1.5          0.2     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 15            5.7          4.4           1.5          0.4     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [118 rows x 5 columns]

# %% [markdown]
# ## changing values to NAN using numpy

# %%
df1 = df
df.iloc[:3, :1] = np.nan
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           NaN          3.5           1.4          0.2  setosa
# 1           NaN          3.0           1.4          0.2  setosa
# 2           NaN          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.iloc[:3, 1:2] = np.NaN
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           NaN          NaN           1.4          0.2  setosa
# 1           NaN          NaN           1.4          0.2  setosa
# 2           NaN          NaN           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## getting the no. of Nan values from each column and getting the position of the Nan values by the Keyword True

# %%
df1.isna()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0            True         True         False        False    False
# 1            True         True         False        False    False
# 2            True         True         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
df1.isna().sum()
# Out:
# sepal_length    3
# sepal_width     3
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# ## filling null values

# %%
# filling null values into multiple cols at once
df1 = df1.fillna({
    'Unnamed: 0' : 0,
    'sepal_length' : df1['sepal_length'].mean()
    
})


#if there are special number which are not related to the data and are used instead for nan
#df = df.replace([num1, num2], np.NaN)
#also colwise (this is when in one col that val should be Nan but not in other)
#df = df.replace({ 'Col1' : np.Nan, 'Col2'...})
#also generally we can do (this is when there are different vals for NaN in each col and not in all col)
#df = df.replace({ 'val1': np.NaN, 'val2': np.Nan})

#suppose there is unit mentioned in some rows of a col eg speed
#df = df.replace({'Col' : [A-Za-z]}, '')

#replace multiple values with multiple values
#df =df.replace([list 1], [Corresponding list])

# new = df1.interpolate() fills null using some math equation
# new

#df1.fillna(method="ffill/bfill(backfill)") forward fill used to fill null value with previous non null val in the same col

#if we want to drop row wise 
# df.dropna(how='all') all here specifies if only all cols are empty for a record then drop the row

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0        5.862585          NaN           1.4          0.2     setosa
# 1        5.862585          NaN           1.4          0.2     setosa
# 2        5.862585          NaN           1.3          0.2     setosa
# 3        4.600000          3.1           1.5          0.2     setosa
# 4        5.000000          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145      6.700000          3.0           5.2          2.3  virginica
# 146      6.300000          2.5           5.0          1.9  virginica
# 147      6.500000          3.0           5.2          2.0  virginica
# 148      6.200000          3.4           5.4          2.3  virginica
# 149      5.900000          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
## groupby
df2 = df1.groupby('species')
df2.get_group('setosa').head(7)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0      5.862585          NaN           1.4          0.2  setosa
# 1      5.862585          NaN           1.4          0.2  setosa
# 2      5.862585          NaN           1.3          0.2  setosa
# 3      4.600000          3.1           1.5          0.2  setosa
# 4      5.000000          3.6           1.4          0.2  setosa
# 5      5.400000          3.9           1.7          0.4  setosa
# 6      4.600000          3.4           1.4          0.3  setosa

# %%
for species, data in df2:
    print(species)
    print(data.head())
# Out:
# setosa
#    sepal_length  sepal_width  petal_length  petal_width species
# 0      5.862585          NaN           1.4          0.2  setosa
# 1      5.862585          NaN           1.4          0.2  setosa
# 2      5.862585          NaN           1.3          0.2  setosa
# 3      4.600000          3.1           1.5          0.2  setosa
# 4      5.000000          3.6           1.4          0.2  setosa
# versicolor
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# virginica
#      sepal_length  sepal_width  petal_length  petal_width    species
# 100           6.3          3.3           6.0          2.5  virginica
# ...

# %%
df2.mean()
#species wise mean/ median/ max/ min
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa          5.063755     3.440426         1.462        0.246
# versicolor      5.936000     2.770000         4.260        1.326
# virginica       6.588000     2.974000         5.552        2.026

# %% [markdown]
# ## pivot

# %%
df_sur= pd.read_csv("C:\\Users\\7XIN\\Desktop\\N2\\AI\\ML\\Supervised learning\\z - Titanic ML project\\train.csv")
df_sur.pivot(index='PassengerId', columns='Survived')
# Out:
#             Pclass                                           Name  \
# Survived         0    1                                         0
# PassengerId
# 1              3.0  NaN                   Braund, Mr. Owen Harris
# 2              NaN  1.0                                       NaN
# 3              NaN  3.0                                       NaN
# 4              NaN  1.0                                       NaN
# 5              3.0  NaN                  Allen, Mr. William Henry
# ...            ...  ...                                       ...
# 887            2.0  NaN                     Montvila, Rev. Juozas
# 888            NaN  1.0                                       NaN
# 889            3.0  NaN  Johnston, Miss. Catherine Helen "Carrie"
# 890            NaN  1.0                                       NaN
# 891            3.0  NaN                       Dooley, Mr. Patrick
#
#                                                                    Sex  \
# ...

# %% [markdown]
# ## Pivot table

# %%
df_sur.pivot_table(index='PassengerId', columns='Survived', aggfunc='sum', margins=True)
# Out:
# C:\Users\7XIN\AppData\Local\Temp\ipykernel_24072\113852649.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   df_sur.pivot_table(index='PassengerId', columns='Survived', aggfunc='sum', margins=True)
# C:\Users\7XIN\AppData\Local\Temp\ipykernel_24072\113852649.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_sur.pivot_table(index='PassengerId', columns='Survived', aggfunc='sum', margins=True)
# ...

# %% [markdown]
# ## reading JSON files

# %%
Data = '[{"Employee_Name" : "Anthony Rodrigues", "Email" : "anthonyrodrigues443@gmail.com", "Job_Profile" : "Data Scientist"} , {"Employee_Name" : "Mark Rodrigues", "Email" : "markrodrigues2004@gmail.com", "Job_Profile" : "Software Engineer Head"}]'
df = pd.read_json(Data)

# %%
df
# Out:
#        Employee_Name                          Email             Job_Profile
# 0  Anthony Rodrigues  anthonyrodrigues443@gmail.com          Data Scientist
# 1     Mark Rodrigues    markrodrigues2004@gmail.com  Software Engineer Head

# %%
df1 = df.to_json(orient="records") #orient='records' saves the json file in row format whereas normally it saves in column form.
df1
# Out:
# '[{"Employee_Name":"Anthony Rodrigues","Email":"anthonyrodrigues443@gmail.com","Job_Profile":"Data Scientist"},{"Employee_Name":"Mark Rodrigues","Email":"markrodrigues2004@gmail.com","Job_Profile":"Software Engineer Head"}]'

# %%
# !pip install lxml
url = 'https://www.w3schools.com/html/html_tables.asp'
df2 = pd.read_html(url,match='Country', header= 0)

# %%
df2[0]
# Out:
#                         Company           Contact  Country
# 0           Alfreds Futterkiste      Maria Anders  Germany
# 1    Centro comercial Moctezuma   Francisco Chang   Mexico
# 2                  Ernst Handel     Roland Mendel  Austria
# 3                Island Trading     Helen Bennett       UK
# 4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
# 5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy

# %%
#creating json files

book = {}
book['tom'] = {'email' : 'tommy@gmail.com', 'country': 'Argentina', 'mobile':9934034925}
book['jerry'] = {'email' : 'jerry@gmail.com', 'country': 'Slovakia', 'mobile':79772354632}

import json
s = json.dumps(book)


books = json.loads(s)
books['tom']['email']
# Out:
# 'tommy@gmail.com'

# %% [markdown]
# ## reading EXCEL files

# %%
# !pip install openpyxl
#also provide sheet name after file name if worbkook has multiple sheets

df_excel = pd.read_excel('read excel file(sample file).xlsx', index_col=0)
df_excel.head()
# Out:
#    age  sex  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  prevalentHyp  \
# 0   54    1             39           0       0                0             0
# 1   35    0             46           0       0                0             0
# 2   71    1             48           1      20                0             0
# 3   74    0             61           1      30                0             0
# 4   78    0             46           1      23                0             0
#
#    diabetes  totChol  sysBP  diaBP  BMI  heartRate  glucose  TenYearCHD  \
# 0         0        0    195  106.0   70      26.97       80          77
# 1         0        0    250  121.0   81      28.73       95          76
# 2         0        0    245  127.5   80      25.34       75          70
# 3         1        0    225  150.0   95      28.58       65          64
# 4         0        0    285  130.0   84      23.10       85          58
#
#    target
# 0       0
# 1       0
# 2       0
# 3       1
# ...

# %%
df_excel.tail()
# Out:
#     age  sex  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 17   53    1             25           0      21                0
# 18   36    1             28           1      26                1
# 19   59    1             31           0      31                1
# 20   57    0             34           1      36                0
# 21   48    0             37           1      34                1
#
#     prevalentHyp  diabetes  totChol  sysBP  diaBP  BMI  heartRate  glucose  \
# 17             1         1        1    234  180.0   94       49.1       56
# 18             0         1        1    289  185.0  101       51.1       76
# 19             1         0        0    344  190.0  108       53.1       85
# 20             0         1        1    267  195.0  115       55.1       46
# 21             1         1        1    210  200.0  122       57.1       75
#
#     TenYearCHD  target
# 17          56       1
# 18          69       0
# 19          82       1
# 20          95       0
# ...

# %% [markdown]
# ## shuffle  module

# %%
from random import shuffle
list_7 = ["Mary", "had", "a", "little", "lamb"]
print(list_7)

shuffle(list_7)
print(list_7)
# Out:
# ['Mary', 'had', 'a', 'little', 'lamb']
# ['lamb', 'had', 'a', 'Mary', 'little']

# %% [markdown]
# ## Converting to a data set

# %%
per = ("mary had", "a", "little", "lamb")
ser = pd.Series(per)
print(ser)

print('\n')

#Converting all words to bold
print(ser.map(lambda x: x.title()))
# Out:
# 0    mary had
# 1           a
# 2      little
# 3        lamb
# dtype: object
#
#
# 0    Mary Had
# 1           A
# 2      Little
# 3        Lamb
# dtype: object

# %%
# Finding the number of characters in each word of present between two ("") double quotes

per = ("mary had", "a", "little", "lamb")
ser = pd.Series(per)

print(ser.map(lambda a: len(a)))
# Out:
# 0    8
# 1    1
# 2    6
# 3    4
# dtype: int64

# %%
##### changing the name of any column

import pandas as pd
df = pd.read_csv('iris.csv', index_col=0)
df_1 = df.rename(columns={'S_length' : 'sepal_length'})
df_1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#reduce module
# !pip install functools
from functools import reduce

sum1 = lambda a,b : a*b
l =[1, 2, 3, 4, 5]#takes the product of first two elements then takes the product of their result with 
fact = reduce(sum1, l)# next num similarly it can perform any operation in the same sequence
fact
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached functools-0.5.tar.gz (4.9 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py clean for functools
# Failed to build functools
# WARNING: Ignoring invalid distribution - (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (c:\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -p (c:\python310\lib\site-packages)
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [1 lines of output]
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
# ...
