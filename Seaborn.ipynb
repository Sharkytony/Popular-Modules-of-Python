# %% [markdown]
# ## -----------------------------------------------SEABORN----------------------------------------

# %%
import seaborn as sns
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.violinplot(data=df, x='size', y='tip')
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
sns.countplot(x=df['day'])
plt.xlabel('Days', size=15)
plt.xticks(fontsize='x-large')
plt.ylabel('Num. of customers', size=15)
plt.yticks(fontsize='x-large')
plt.title('Customers per day', size=15)
# plt.plot(df['tip'])
plt.show()

# %%
sns.histplot(df['tip'])
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.jointplot(x=df['total_bill'], y=df['tip'], hue=df['smoker'], kind='scatter')
plt.xlim(0, None)
plt.ylim(0, None)
plt.show()

# %%
sns.scatterplot(df['tip'], df['size'], hue=df['day'])
# Out:
# C:\Users\7XIN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='tip', ylabel='size'>

# %%
#unadvised since x scale is a continous feature (here the data is small and we get insights from the catplot).
sns.catplot(x='total_bill', y='tip', hue='smoker', data=df)

# %%
sns.countplot(df['time'])
# Out:
# C:\Users\7XIN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='time', ylabel='count'>

# %%
sns.distplot(df['size'])
# Out:
# C:\Users\7XIN\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='size', ylabel='Density'>

# %%
import seaborn as sns
import pandas as pd

# %%
df1 = sns.load_dataset('iris')

# %%
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df1.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(df1.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Univariate analysis

# %%
import numpy as np
df1_setosa = df1.loc[df1['species'] == 'setosa']
df1_virginica = df1.loc[df1['species'] == 'virginica']
df1_versicolor = df1.loc[df1['species'] == 'versicolor']
np.zeros_like
# Out:
# <function numpy.zeros_like(a, dtype=None, order='K', subok=True, shape=None)>

# %%
import matplotlib.pyplot as plt
plt.scatter(df1_setosa['sepal_length'], np.zeros_like(df1_setosa['sepal_length']))
plt.scatter(df1_virginica['sepal_length'], np.zeros_like(df1_virginica['sepal_length']))
plt.scatter(df1_versicolor['sepal_length'],np.zeros_like(df1_versicolor['sepal_length']))
plt.xlabel('Petal length')
plt.show()

# %% [markdown]
# Bivarite analysis

# %%
sns.catplot(x='sepal_length',y='sepal_width',hue='species',palette='CMRmap', data=df1)

# %%
sns.barplot(x='petal_length',y='petal_width',hue='species',data=df1,palette='Accent')
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
sns.displot(df1['sepal_length'], kde=True, palette='Accent_r', bins=15)

# %%
sns.histplot(data=df1, x='sepal_width', bins=5, palette='RdBu')
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='Count'>

# %%
sns.boxplot(data=df1)
# Out:
# <AxesSubplot:>

# %%
sns.displot(data=df1, x='petal_length', y='sepal_length', hue='species')

# %%
sns.catplot(x='sepal_length', y='petal_width', data= df1, hue='species') #works same as catplot
plt.xticks(rotation=90, fontsize="xx-small")
plt.show()

# %% [markdown]
# Multivariate analysis

# %%
sns.jointplot(x='sepal_width', y='petal_length', hue='species', data=df1, kind='scatter', color='m')

# %%
sns.kdeplot(x='sepal_width',y='petal_width',data=df1, )
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='petal_width'>

# %%
sns.countplot(x='species', data=df1)
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
sns.pairplot(data=df1, hue='species')

# %% [markdown]
# ## PyForest
# ### PyForest is a library that imports all Data Science libraries
